# %% [markdown]
# Make sure you report on the following minimal requirements:
#
# 1) A methodology section is required. At the top of your notebook, and before any code sections, write down your methodological approach for each of the three questions.
# 2) Executive summary of results is required. At the end of your notebook, develop an executive summary to outline the questions and their objectives, summarize your methods, and develop a discussion narrative formulated as an answer to each of the
# proposed questions.

# %% [markdown]
# You are a climate data analyst working for the Fire Emergency New Zealand national fire risk
# team. You have been tasked to develop a methodology, implement it, and produce results
# addressing the following questions:

# %% [markdown]
# # Methodology
#
# ## General
#
# ### Data source
#
# <!-- Data source and provenance - full name of dataset incl version where applicable. Organisation responsible for data collection. How the author (me) accessed the data. Date accessed or downloaded. -->
#
# Data for this study was from the Met Service Fire Weather Index dataset, which holds fire weather index predictions based on weather model data from 2001 through 2019. Data was collected by the New Zealand Meteorological Service and accessed via University of Canterbury's GSDS department server in September 2026.
#
# <!-- Which records from the full dataset were included in the current analysis and why. Any exclusions - why records were excluded and how many -->
#
# Only data for the months of December, January, February and March were included in the analysis. The rest of the year is considered low risk for fires in New Zealand and was therefore excluded.
#
# <!-- How variables in the dataset were used in the interest of the current study. Any transformation of variables. -->
#
# <!-- How missing data were handled. -->
#
# <!-- For question 1:
# * You are required to develop a SOM from the FWI data.
# * You are required to choose and justify your choice of hyper parameter settings for your SOM.
# * Extremes are defined by the top 5% of your data. Use percentile approaches like demonstrated in Lab 07.
# * To select your most extreme node, you need to show a quantifiable metric on how you have chosen the node. This can include, for example, largest number of pixels above certain FWI threshold or similar
# -->
#
# ### Methodology
#
# <!-- What I did: built a SOM -->
#
# <!-- Data preparation -->
#
# <!-- Hyperparameters for the SOM -->
#
# <!--
#
# Methodology: how you approached the project. Organise by research question and analytical stage.
# * Quantitative - measurement, sample, statistical analysis.
# * This section should answer who or what was studied, what was done, how data were collected, how data were analysed.
# * Write in the past tense.
# * Secondary Data Analysis: uses data collected by someone else for a different original purpose. is that the case here, or was the original purpose the same? I think it probably counts as the same.
# * Analytical approach: statistical models or analytic methods
#
# Common mistakes:
# * citing the data without describing it
# * not describing how abstract constructs of the study goals were mapped onto specific variables in the dataset
# * ommitting access date
# * ignoring design effects (hoh?)
#
# Methods: what you actually did
# -->

# %% [markdown]
# ## Question 1: What areas in New Zealand have been experiencing extreme FWI conditions over the last 20 years?
#
# ### Code and results

# %% [markdown]
# #### Import required libraries

# %%
import os
from glob import glob
from time import time
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from minisom import MiniSom
import pymannkendall as mk

# %% [markdown]
# #### Load the files

# %%
# Path to the main folder containing the subfolders with the FWI .nc files
main_folder = "/mnt/data/MetService_FWI"

# Recursively find all .nc files in subfolders
nc_files = glob(os.path.join(main_folder, "**", "*.nc"), recursive=True)

# %%
# Open and combine all netCDF files into one dataset
full_dataset = xr.open_mfdataset(
    nc_files,
    combine="by_coords",
    chunks='auto',
)

# %%
# Utility functions adapted from fwi_som_helper.py
def min_max_scaling(data):
    # Calculate the minimum and maximum values for each feature
    min_vals = data.min()
    max_vals = data.max()
    
    # Perform min-max scaling
    scaled_data = (data - min_vals) / (max_vals - min_vals)
    return scaled_data

def preprocess(data_array):
    # Stack lat/lon -> "space" dimension
    X = data_array.stack(space=('lat','lon')).transpose('time', 'space')

    # Drop grid cells (space) that are all-NaN across time
    X = X.dropna(dim='space', how='all')

    # Fill remaining NaNs with 0 (simple demo choice)
    X = X.fillna(0.0)

    # Scale the data
    preprocessed = min_max_scaling(X)
    return X, preprocessed

def som_distance_map(ax, som, training_data, title):
    u = som.distance_map()
    mappable = ax.imshow(u, origin='upper', cmap='bone_r')
    ax.set_title(title, fontsize=8)
    ax.set_xlabel('j (x-axis of SOM grid)')
    ax.set_ylabel('i (y-axis of SOM grid)')
    ar = som.activation_response(training_data)
    for x in range(ar.shape[0]):
        for y in range(ar.shape[1]):
            freq = ar[x, y]
            if freq > 0:
                ax.plot(x, y, 'ro', markersize=np.sqrt(freq)*2, alpha=0.6)
    return mappable

# %%
# SUMMER_MONTHS: a constant value encapsulating month indices for December through March
SUMMER_MONTHS = [12, 1, 2, 3 ]
summer_mask = full_dataset.time.dt.month.isin(SUMMER_MONTHS)

# Select the data for those months
full_dataset_summer_months = full_dataset.sel(time=summer_mask)

# Run through the preprocessing helper
original_data, preprocessed = preprocess(full_dataset_summer_months['FWI'])

# %% [markdown]
# #### Hyperparameter selection
#
# To determine the best settings for training I performed the below hyperparameter search: iterating over several values of neighbourhood size (sigma) and learning rate and visualising results to help guide parameter selection. The U-Matrix includes red dots to indicate the activation response for each node: how many times that node has been selected as the best matching unit for the input data.

# %%
# Constants
SOM_X = 5
SOM_Y = 5
NUM_ITERATIONS = 10000

results = {}
training_data = preprocessed.values

for x, sigma in enumerate([1.0, 2.0, 3.0]):
    fig, axes = plt.subplots(1, 4, figsize=(16, 4))
    results[sigma] = {}
    for y, lr in enumerate([0.01, 0.05, 0.1, 0.5]):
        som = MiniSom(
            x=SOM_X, y=SOM_Y,
            input_len=training_data.shape[1],
            sigma=sigma,
            learning_rate=lr,
            neighborhood_function='gaussian',
            random_seed=42
        )

        som.random_weights_init(training_data)
        som.train_random(training_data, num_iteration=NUM_ITERATIONS, verbose=False)
        qe = som.quantization_error(training_data)
        te = som.topographic_error(training_data)
        results[sigma][lr] = qe

        title = f"S={sigma}, LR={lr}: QE={qe:.3f}, TE={te:.3f}."
        print(f"Trained SOM: sigma={sigma}, learning rate={lr}: QE={qe}, TE={te}.")
        mappable = som_distance_map(axes[y], som, training_data, title)
        som = None

    fig.colorbar(mappable, ax=axes.ravel().tolist(), orientation='vertical', label='avg neighbour distance')
    plt.grid(False)
    plt.show()
# Out:
# Trained SOM: sigma=1.0, learning rate=0.01: QE=4.552765101306069, TE=0.24725943970767356.
# Trained SOM: sigma=1.0, learning rate=0.05: QE=4.454342591032769, TE=0.15468940316686966.
# Trained SOM: sigma=1.0, learning rate=0.1: QE=4.453595056883945, TE=0.1851400730816078.
# Trained SOM: sigma=1.0, learning rate=0.5: QE=4.651866469197745, TE=0.583028826634186.
# Trained SOM: sigma=2.0, learning rate=0.01: QE=4.6808028275432045, TE=0.02639058059277304.
# Trained SOM: sigma=2.0, learning rate=0.05: QE=4.635240851059778, TE=0.015834348355663823.
# Trained SOM: sigma=2.0, learning rate=0.1: QE=4.6345373165744626, TE=0.01908241981323589.
# Trained SOM: sigma=2.0, learning rate=0.5: QE=4.703998793621063, TE=0.05278116118554608.
# Trained SOM: sigma=3.0, learning rate=0.01: QE=4.8200001348054755, TE=0.005684125050751117.
# Trained SOM: sigma=3.0, learning rate=0.05: QE=4.779199457786762, TE=0.006902151847340642.
# ...

# %% [markdown]
# To select a set of hyperparameters, I looked at some general qualities of the U-Matrix:
# * Smooth gradients between the cells, so the cells look like they're arranged rather than randomly scattered in the matrix.
# * Defined boundaries between dark and light areas.
#
# In addition, the red dots indicate the frequency of values in each cluster. The largest dots ought to occur on the lightest cells, because those cells should be representing the 'standard' or most common data points. The smallest dots should occur on the dark cells, because those cells represent the most extreme values, which by definition should have a low frequency within the data.
#
# As well as the above, I spot-checked some of the parameter combinations with a larger number of training iterations and with a smaller number of SOM grid cells. But found that 5x5 still provided the best error rate, and increasing the number of iterations did not lower the error rates.
#
# Based on the hyperparameter search I settled on parameters `SIGMA=3`, `LEARNING_RATE=0.01`, `NUM_ITERATIONS=10000`.

# %% [markdown]
# #### Train the SOM
#
# With the selected parameters we now train the SOM.

# %%
# Constants
SOM_X = 5
SOM_Y = 5
NUM_ITERATIONS = 10000
SIGMA = 3.0
LEARNING_RATE = 0.1

som = MiniSom(
    x=SOM_X, y=SOM_Y,
    input_len=training_data.shape[1],
    sigma=SIGMA,
    learning_rate=LEARNING_RATE,
    random_seed=42
)
som.random_weights_init(training_data)
som.train_random(training_data, num_iteration=NUM_ITERATIONS, verbose=True)

qe = som.quantization_error(training_data)
te = som.topographic_error(training_data)

print(f"Trained SOM: {SOM_X}x{SOM_Y} sigma={SIGMA} learning rate={LEARNING_RATE} with {NUM_ITERATIONS} iterations. quantisation error={qe:.4f}, topographic error={te:.4f}")
# Out:
#  [ 10000 / 10000 ] 100% - 0:00:00 left
#  quantization error: 4.783436035732565
# Trained SOM: 5x5 sigma=3.0 learning rate=0.1 with 10000 iterations. quantisation error=4.7834, topographic error=0.0097

# %% [markdown]
# #### Group the data into best matching units

# %%
# For each value in preprocessed data, find the SOM node that it best goes in.
# One 'value' = an array of numbers. The numbers are FWI values without any
# lat/lon coordinate or time stamp, but at this point those coordinates don't
# matter because we're only figuring out the frequencies of values.
bmus = [som.winner(s) for s in preprocessed.values]

# Associate each BMU decision to the label of the node that was selected for it
labels = np.array([i * SOM_Y + j for (i, j) in bmus])

# Turn this into a data array
som_labels = xr.DataArray(
    labels,
    coords={'time': preprocessed['time']},
    dims=['time'],
    name='som_label'
)

# Frequency table
unique, counts = np.unique(labels, return_counts=True)
freq = dict(zip(unique, counts))

# %% [markdown]
# #### Plot prototype maps
#
# These maps help to visualise the clustering that is achieved in the SOM. Visually we can verify that the last node has collected the bulk of the extreme values.

# %%
# Prototype maps
proto_maps = helper.create_proto_maps(som, SOM_X, SOM_Y, original_data)

max_val = proto_maps.max().values
print(f"The average maximum FWI value is {float(max_val):0.2f}")

min_value = float(proto_maps.quantile(0.0))
max_value = float(proto_maps.quantile(1.0))

helper.plot_som_maps(proto_maps, SOM_X, SOM_Y, min_value, max_value, cmap="jet")
# Out:
# The average maximum FWI value is 34.95

# %% [markdown]
# To answer the question "what areas are experiencing extreme conditions" we
# need to define the 'extreme conditions' threshold as being the top 5% of the data.

# %%
# Threshold value for being top 5%
threshold = float(original_data.quantile(0.95))
threshold
# Out:
# 14.7849760055542

# %% [markdown]
# #### The 5% threshold is an FWI value of 14.78 or higher
#
# On a national scale, a FWI value of 15 or more represents a high fire danger, so this threshold seems reasonable.
#
# #### Create percentile maps

# %%
# This code was adapted from fwi_som_helper.py
maps = []
for n in range(SOM_X * SOM_Y):
    # Select all measurements from the original dataset that should belong to this unit
    members = original_data.where(som_labels == n, drop=True)

    # The 'quantile' function sorts the values in 'members' from lowest to highest, and determines the 95th percentile mark
    # -> 95% of the days that this node occurred had FWI values lower than this number
    # -> only 5% of days when this node occurred had FWI value at or above this number
    # 'field' at this point is a DataArray with coordinates space, lat, lond, and quantile
    field = members.quantile(0.95, dim="time")

    # Remove the 'quantile' coordinate (it just contains the value 95)
    if "quantile" in field.coords:
        field = field.drop_vars("quantile")

    # Add a 'unit' dimension to represent which node these values are assigned to
    field = field.expand_dims(unit=[n])

    # 'field' at this point is a spatial map of the 95th percentile values in node n
    maps.append(field)

# Join all the maps together. The new DataArray has a 'unit' dimension to indicate
# the node of the SOM that data has landed in.
percentile_maps = xr.concat(maps, dim="unit")

# Convert the stacked 'space' dimension back to lat/lon
percentile_maps = (
    percentile_maps
    .unstack("space")
    .sortby("lat")
    .sortby("lon")
)

# in the percentile maps, consider each grid pixel at a particular
# lat/lon within one SOM node to be a cell holding a scalar value.
# The value stored in that cell is the FWI threshold that was exceeded
# on only the top 5% worst fire-weather days that occurred on the time
# slices that landed in the cell.

# For each node in the map, how many cells were above that threshold?
extreme_pixels_per_node = (percentile_maps > threshold).sum(dim=['lat', 'lon'])

# Which node has the most extreme cells?
extreme_node = int(np.argmax(extreme_pixels_per_node.values))

print(f'The node with the most extreme values is unit {extreme_node}')
# Out:
# The node with the most extreme values is unit 24

# %% [markdown]
# #### Location plot of the most extreme FWI values in the last 20 years

# %%
# Plot helper adapted from fwi_som_helper.py
def plot_with_coasts_no_ocean(
    da2d: xr.DataArray,
    *,
    cmap: str = "viridis",
    vmin: float | None = None,
    vmax: float | None = None,
    cbar_label: str | None = None,
    coastline_res: str = "10m",
    title: str | None = None,
    figsize=(7, 7),
):
    """
    Plot a 2D (lat, lon) DataArray with coastlines and oceans masked to white.
    Parameters
    ----------
    da2d : xr.DataArray
        2D data with latitude/longitude coordinates. If your data has a time
        dimension, pass a single time slice (e.g., da.sel(time='2010-01-08')).
    cmap : str
        Matplotlib colormap name.
    vmin, vmax : float or None
        Color scale limits. If None, inferred from the data.
    cbar_label : str or None
        Colorbar label.
    coastline_res : {'10m','50m','110m'}
        Cartopy coastline resolution.
    title : str or None
        Plot title.
    figsize : tuple
        Figure size in inches.
    """
    # --- Find lat/lon coord names
    lat_name = None
    lon_name = None
    for cand in ("lat", "latitude", "y"):
        if cand in da2d.coords:
            lat_name = cand
            break
    for cand in ("lon", "longitude", "x"):
        if cand in da2d.coords:
            lon_name = cand
            break
    if lat_name is None or lon_name is None:
        raise ValueError("Could not find latitude/longitude coords in DataArray.")

    if da2d.ndim != 2:
        # If it has extra dims (e.g., time), ask user to select one
        extra = [d for d in da2d.dims if d not in (lat_name, lon_name)]
        raise ValueError(
            f"Expected 2D DataArray (lat, lon). Found dims {da2d.dims}. "
            f"Select a slice first (e.g., da.sel(time=...)). Extra dims: {extra}"
        )

    proj = ccrs.PlateCarree()
    fig, ax = plt.subplots(figsize=figsize, subplot_kw={"projection": proj})
    nz_extent = [165, 180, -48.8, -33.5]

    # Plot the data
    im = da2d.plot(
        ax=ax,
        transform=proj,
        cmap=cmap,
        vmin=vmin,
        vmax=vmax,
        add_colorbar=True,
        cbar_kwargs={"label": cbar_label, "shrink": 0.8} if cbar_label else None,
    )

    # Mask oceans visually (draw ocean polygons on top, filled white)
    ax.add_feature(cfeature.OCEAN, facecolor="white", edgecolor="none", zorder=10)

    # Coastlines on top
    ax.coastlines(resolution=coastline_res, linewidth=0.8, zorder=20)

    # Tighten extent to the data grid
    ax.set_extent(nz_extent, crs=ccrs.PlateCarree())
    
    if title:
        ax.set_title(title)

    plt.show()

# %%
extreme_node_map = percentile_maps.sel(unit=extreme_node)
mask = extreme_node_map > threshold

total_extreme_pixels = int(mask.sum().values)
total_nz_land_pixels = original_data.sizes['space']
pct_nz_grid = (total_extreme_pixels / total_nz_land_pixels) * 100

plot_with_coasts_no_ocean(
    extreme_node_map,
    cmap='YlOrRd',
    cbar_label="95th percentile FWI",
    title=f"95th percentile FWI values (node {extreme_node})"
)

# %% [markdown]
# ### Discussion (DRAFT - TODO REFINE)

# %% [markdown]
# #### 1. Geographic patterns
#
# The spatial map of the most extreme SOM node reveals that the most extreme fire ewather conditions in New Zealand are concentrated in the eastern side of the country, primarily the Canterbury Plains, Central Otago and Waitaki in the South Island; and Hawke's Bay, Gisborne and the Wairarapa in the North Island.
#
# These areas all lie in the lee of mountain ranges that create a 'rain shadow'. When strong westerly to north-westerly winds occur, they warm on the way down the eastern slopes of the mountains and create a combination of high temperatures, low relative humidity, and strong surface winds. That combination leads to fire weather index values.
#
# #### 2. National Threshold and Spatial Extent Quantification
#
# Across the whole 20 year dataset, the national 95th percentile threshold was calculated as FWI = 14.78. Wet regions such as the South Island's western coastline have quite consistentlow low FWI values throughout the summer, which moderates the overall national values.
#
#
#
# Evaluating the extreme SOM node against this national benchmark demonstrated that the active extreme pattern impacts approximately 67% of New Zealand's analyzed land grid. While the synoptic weather state creates elevated fire risk across a broad national footprint, the severe, high-end FWI intensities remain tightly confined to the eastern rain-shadow corridors.
#
# #### 3. Commentary on Weather Model Performance and Limitations (Assignment 2 Context)
#
# Because the FWI dataset is derived from gridded Numerical Weather Prediction (NWP) model outputs rather than direct ground station measurements, several model validation metrics and limitations from Assignment 02 must be considered when interpreting these conclusions:
#
# Spatial Resolution and Topographic Smoothing: Numerical weather models average atmospheric variables over discrete grid cells. In complex terrain (such as the Canterbury foothills or river valleys), this spatial averaging smooths out hyper-localized microclimates, funnelled wind gusts, and extreme drops in relative humidity. Consequently, the 67% spatial footprint represents a macro-scale synoptic risk zone, whereas ground-level fire danger in specific valleys may be significantly higher than modelled.
#
# Systematic Bias in Tail Events: NWP models frequently exhibit smoothing biases during extreme weather events—such as slightly underestimating peak summer temperatures or overestimating minimum relative humidity. Because the FWI algorithm responds non-linearly (exponentially) to wind speed and humidity, even minor model underestimates in atmospheric extremes lead to a disproportionate underestimation of peak FWI scores.
#
# Operational Impact: The modelled threshold of 14.78 and the corresponding node maps should be viewed as a conservative baseline. Actual ground-level extreme fire danger experienced at weather stations during peak Foehn events likely exceeds these gridded values.
#
# #### 4. Operational Implications for Fire Emergency New Zealand (FENZ)
#
# For national fire risk management, these results demonstrate that extreme fire weather is not uniformly distributed but is instead driven by specific synoptic states that selectively impact eastern New Zealand. FENZ national risk teams should utilize these SOM synoptic patterns for early warning forecasting, while pairing gridded model predictions with real-time Automatic Weather Station (AWS) observations to account for model smoothing during active Foehn wind events.

# %% [markdown]
# ## Question 2:  Which months in the defined fire season are we usually experiencing more extreme FWI conditions over the last 20 years?
#
# ### Code and results

# %%
# To answer this question we need to break down
# the FWI values monthly and create histograms

# Temporal Frequency Histogram: How many days in each month (Dec, Jan, Feb, Mar) 
# were assigned to your winning extreme SOM node across the 20-year period?

# Spatial/Value Distribution Histograms: How do the actual FWI values
# distribute across those extreme node days when broken down by month?

# %%
# Frequency of extreme node days by month

# Filter som_labels for timesteps assigned to your extreme node
extreme_day_labels = som_labels.where(som_labels == extreme_node, drop=True)

# Extract the month integer (12, 1, 2, 3) for each extreme day
extreme_months = extreme_day_labels.time.dt.month.values

# Count occurrences for each summer month
month_names = ["Dec", "Jan", "Feb", "Mar"]
counts = [np.sum(extreme_months == m) for m in summer_months]

# Plot a histogram
plt.figure(figsize=(8, 5))
bars = plt.bar(month_names, counts, color="darkorange", edgecolor="black")
plt.title(
    f"Occurrence of Extreme SOM Pattern (Node {extreme_node}) by Month (2000–2020)"
)
plt.xlabel("Fire Season Month")
plt.ylabel("Number of Extreme Days")
plt.grid(axis="y", linestyle="--", alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2.0,
        yval + 0.5,
        int(yval),
        ha="center",
        va="bottom",
        fontweight="bold",
    )

plt.tight_layout()
plt.show()

# %%
# Calculate the max pixel count - this will be the maximum y axis value
# across all 4 histograms
max_pixel_count = 0
for m in summer_months:
  m_data = extreme_node_days.where(extreme_node_days.time.dt.month == m, drop=True)
  fwi_vals = m_data.values.flatten()
  fwi_vals = fwi_vals[~np.isnan(fwi_vals)]
  if len(fwi_vals) > 0:
    counts, _ = np.histogram(fwi_vals, bins=bins)
    if len(counts) > 0:
      max_pixel_count = max(max_pixel_count, counts.max())

# Add 5% top padding so the highest bar doesn't touch the top frame
max_y_limit = max_pixel_count * 1.05 if max_pixel_count > 0 else 100

# Create subplots for the 4 fire season months
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

# Filter original unscaled FWI data for extreme node days only
extreme_node_days = original_data.where(som_labels == extreme_node, drop=True)

max_fwi_val = float(np.nanmax(original_data.values))
bins = np.linspace(0, max_fwi_val, 31)

# For each month
for i, (m, name) in enumerate(zip(summer_months, month_names)):
    # Select extreme node data for the current month
    m_data = extreme_node_days.where(
        extreme_node_days.time.dt.month == m, drop=True
    )
    # Drop empty time slices
    m_data = m_data.dropna(dim="time", how="all")

    # Flatten values and drop NaNs
    fwi_vals = m_data.values.flatten()
    fwi_vals = fwi_vals[~np.isnan(fwi_vals)]

    # Plot histogram for this month
    axes[i].hist(
        fwi_vals, bins=bins, color="darkorange", edgecolor="black", alpha=0.8
    )
    axes[i].set_xlim(0, max_fwi_val)
    axes[i].set_ylim(0, max_y_limit)
    axes[i].set_xlabel("FWI Value")
    axes[i].set_title(f"{name} (n={len(m_data.time)} extreme days)")
    axes[i].set_ylabel("Pixel Frequency")
    axes[i].grid(True, linestyle="--", alpha=0.5)

    # Draw a line at the national 95th percentile
    axes[i].axvline(
        threshold,
        color="red",
        linestyle="dashed",
        linewidth=2,
        label=f"95th Pct Threshold ({threshold:.1f})",
    )
    axes[i].legend()

# Shared x-axis label
fig.supxlabel("FWI Value")
fig.suptitle(
    f"Distribution of FWI Values Across Extreme Node {extreme_node} Days by Month",
    fontsize=14,
    fontweight="bold",
)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Discussion (DRAFT: TODO REVISE THIS)
#
# #### 1. Dominance of January as the Peak Extreme Month
#
# Across the 20-year fire season dataset (01 December to 31 March, 2000–2020), the temporal frequency histogram and FWI pixel distribution plots demonstrate that January is the peak month by far for extreme fire weather conditions in New Zealand1more_horiz.Temporal Frequency: Days assigned to the winning extreme SOM synoptic pattern occur with significantly higher frequency in January than in any other month34.Spatial and Value Distribution: When evaluating the spatial pixel distribution of raw FWI values on extreme node days, January exhibits both the highest volume of grid pixels exceeding the national $95^{\text{th}}$ percentile benchmark ($\text{FWI} = 14.78$) and the longest right-side tail into peak FWI values ($>30–50+$)4.
#
# #### 2. Climatological and Physical Rationale
#
# The pronounced concentration of extreme fire danger in January is driven by the interaction of atmospheric synoptic patterns and cumulative seasonal drying:
# Cumulative Soil and Fuel Deficits: During December, summer heat increases, but residual spring soil moisture and live vegetation fuel moisture often moderate the initial rise in FWI. By January, weeks of high solar radiation and evapotranspiration severely deplete fine fuel and duff moisture levels, leaving vegetation highly receptive to rapid fire spread.
# Peak Synoptic Weather Setups: Mid-summer atmospheric blocking patterns over New Zealand frequently position persistent high-pressure systems to the east while deep troughs pass to the south. This setup drives strong, warm westerly to north-westerly airflows across the Southern Alps, generating intense Foehn wind drying events across Canterbury, Otago, Marlborough, and the North Island's East Coast.
# Late-Season Decline (February–March): While February maintains elevated risk due to lingering drought conditions, total solar irradiance begins to decline. By March, cooler night-time temperatures and increasing autumn humidity begin to suppress background FWI levels across most regions.
#
# #### 3. Operational Implications for Fire Emergency New Zealand (FENZ)
#
# For national fire risk management, these findings provide clear seasonal timelines for resource planning
# :
# Targeted Asset Pre-positioning: FENZ should schedule peak operational readiness, seasonal staffing, and aerial firefighting asset deployments to peak during the January window.
# Public Risk Communication: High-level public warnings, total fire bans (Prohibited Fire Seasons), and restriction enforcement should be aggressively implemented entering January, as the probability of atmospheric synoptic setups aligning with extreme ground-level fuel dryness is highest during this month.

# %% [markdown]
# ## Question 3:  Is Canterbury experiencing an increasing trend of extreme FWI days over the last 20 years?
#
# To answer this we need to extract the data for Darfield (our representative Canterbury location) and run a Mann-Kendall trend test to see if there is an upwards trend in extreme fire days.

# %%
original_data
# Out:
# <xarray.DataArray 'FWI' (time: 2463, space: 44358)> Size: 437MB
# dask.array<where, shape=(2463, 44358), dtype=float32, chunksize=(29, 44358), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) datetime64[ns] 20kB 2000-01-02 2000-01-03 ... 2020-12-31
#   * space    (space) object 355kB MultiIndex
#   * lat      (space) float64 355kB -47.37 -47.37 -47.31 ... -34.34 -34.31 -34.31
#   * lon      (space) float64 355kB 167.5 167.5 167.5 167.5 ... 173.0 173.0 173.0

# %%
# Darfield location
DARFIELD_LAT = -43.48
DARFIELD_LON = 172.11

# 1. Baseline time series: select all summer days at Darfield (original_data is already
# filtered to just the summer months)
darfield_baseline = full_dataset_summer_months['FWI'].sel(
    lat=DARFIELD_LAT, lon=DARFIELD_LON, method="nearest"
)
print(
    f"Baseline days count at Darfield: {len(darfield_baseline.time)}"
)  # ~2,420 days

# 2. Extreme node time series: summer days at Darfield just from the most extreme SOM node
darfield_extreme_node = darfield_baseline.where(som_labels == extreme_node, drop=True)

print(
    f"Extreme node days count at Darfield: {len(darfield_extreme_node.time)}"
)

# Season year coordinate for FULL time series (~2,420 days)
season_year_full = som_labels.time.dt.year + (
    som_labels.time.dt.month == 12
).astype(int)
season_year_full.name = "season_year"

# Season year coordinate for EXTREME NODE subset (~150 days)
season_year_extreme = darfield_extreme_node.time.dt.year + (
    darfield_extreme_node.time.dt.month == 12
).astype(int)
season_year_extreme.name = "season_year"

# Find the annual frequency of extreme node days
annual_extreme_counts = (
    som_labels.where(som_labels == extreme_node)
    .groupby(season_year_full)
    .count(dim="time")
)
print('annual_extreme_counts', annual_extreme_counts)

# get the annual maximum FWI at Darfield during those extreme node days
darfield_grouped = darfield_extreme_node.groupby(season_year_extreme)
print('darfield_grouped', darfield_grouped)

annual_extreme_fwi_max = darfield_extreme_node.groupby(season_year_extreme).max(dim="time")
print(annual_extreme_fwi_max)

# 3. Annual baseline 90th percentile FWI at Darfield
annual_baseline_p90 = darfield_baseline.groupby(season_year_full).quantile(0.90, dim='time')
# Out:
# Baseline days count at Darfield: 2463
# Extreme node days count at Darfield: 175
# annual_extreme_counts <xarray.DataArray 'som_label' (season_year: 22)> Size: 176B
# array([ 5, 11,  2,  8, 13,  8,  5,  2,  7, 11,  5,  3,  3, 17,  8, 11,  7,
#        10,  5, 16, 16,  2])
# Coordinates:
#   * season_year  (season_year) int64 176B 2000 2001 2002 2003 ... 2019 2020 2021
# darfield_grouped <DataArrayGroupBy, grouped over 1 grouper(s), 22 groups in total:
#     'season_year': UniqueGrouper('season_year'), 22/22 groups with labels 2000, 2001, 2002, ..., 2020, 2021>
# <xarray.DataArray 'FWI' (season_year: 22)> Size: 88B
# dask.array<stack, shape=(22,), dtype=float32, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#   * season_year  (season_year) int64 176B 2000 2001 2002 2003 ... 2019 2020 2021
#     lat          float64 8B -43.47
#     lon          float64 8B 172.1

# %%
print("=== MANN-KENDALL TEST: Extreme Day Frequency ===")
mk_counts = mk.original_test(annual_extreme_counts.values)
print(f"Trend:         {mk_counts.trend}")
print(f"p-value:       {mk_counts.p:.4f}")
print(f"Sen's Slope:   {mk_counts.slope:.4f} days/year\n")
# Out:
# === MANN-KENDALL TEST: Extreme Day Frequency ===
# Trend:         no trend
# p-value:       0.5313
# Sen's Slope:   0.1250 days/year

# %%
print("=== MANN-KENDALL TEST: Darfield Baseline 90th Pct FWI ===")
mk_baseline = mk.original_test(annual_baseline_p90.values)
print(f"Trend:         {mk_baseline.trend}")
print(f"p-value:       {mk_baseline.p:.4f}")
print(f"Sen's Slope:   {mk_baseline.slope:.4f} FWI units/year")
# Out:
# === MANN-KENDALL TEST: Darfield Baseline 90th Pct FWI ===
# Trend:         no trend
# p-value:       0.2839
# Sen's Slope:   0.1989 FWI units/year

# %% [markdown]
# #### No trend! I'm surprised
#
# Climate data over a 20-year window (2000–2020) is heavily dominated by short-to-medium-term climate drivers like the El Niño–Southern Oscillation (ENSO) and the Southern Annular Mode (SAM)
#
# Hot, dry El Niño years trigger sharp spikes in fire weather, while cooler or wetter La Niña years drop back down.
#
# Because the sample size is only 20 annual data points ($N = 20$), this high year-to-year scatter creates "noise" that masks long-term background climate shifts
#
# Sen's slope outputs:
#
# Extreme Day Frequency: $+0.1250$ days/year (equivalent to $+2.5$ additional extreme days per decade)
#
# Baseline 90th Percentile FWI: $+0.1989$ FWI units/year (equivalent to $+2.0$ FWI points per decade)
#
# The slope is positive for both metrics, indicating a mild upward trajectory over time. However, because of the large year-to-year swings, the Mann–Kendall test ($p = 0.5313$ and $p = 0.2839$) cannot confirm with 95% confidence ($\alpha = 0.05$) that this upward slope is a true monotonic trend rather than random interannual variability.
#
# #### Discussion draft content
#
# 1. Statistical Trend Detection (Mann–Kendall & Sen's Slope)Non-parametric Mann–Kendall trend testing was conducted for the Darfield location across the 20-year record (2000–2020)
#
# Extreme Day Frequency: Showed no statistically significant trend ($p = 0.5313, \alpha = 0.05$)
#
# Sen's slope estimator indicated a slight positive trajectory of $+0.1250$ days/year ($+2.5$ extreme days per decade)24.Baseline 90th Percentile FWI Severity: Showed no statistically significant trend ($p = 0.2839, \alpha = 0.05$)
#
# Sen's slope indicated a modest increase of $+0.1989$ FWI units/year.
#
# While global climate projections anticipate an increase in fire risk across eastern New Zealand, failing to reject the null hypothesis ($H_0$: no monotonic trend) over a 20-year window is attributable to key physical factors.
#
# Dominance of Interannual Variability: Fire weather in Canterbury is strongly regulated by decadal climate modes such as ENSO and SAM. Severe fire seasons (e.g., 2003/04, 2014/15, and 2019/20) are interspersed with damp, low-risk seasons, creating high statistical variance that obscures long-term background signals over a short 20-year sample ($N=20$).
#
# Signal-to-Noise Ratio: Although Sen's slope shows a positive rate of change ($+2.5$ extreme days/decade), 20 years is relatively short in climate analytics for a monotonic trend signal to overcome natural atmospheric noise. Detecting a statistically significant background trend typically requires a 30- to 50-year observation window.
#
# Model Smoothing Influences: As noted in the Assignment 2 model validation context, gridded numerical weather models tend to smooth out extreme localized Foehn-wind spikes. This spatial smoothing may slightly dampen the interannual trend magnitude compared to raw ground station records.
#
# Summary for Fire Emergency New Zealand (FENZ)
#
# From an operational perspective, while extreme fire weather has not exhibited a statistically significant upward acceleration at Darfield over 2000–2020, the baseline fire danger remains persistently high during peak summer months. FENZ operational planning should focus on managing high interannual volatility—preparing for severe spike years driven by El Niño setups—rather than assuming a steady year-on-year increase.

# %% [markdown]
# # Executive Summary
#
#
# "The maximum FWI value in the prototype maps is 34.95" - NZ's overall average maximum is over the global 'extreme' limit of 32!
#
# Model Validation Context (Ass 02):
#
# "The FWI dataset utilized in this analysis is derived from gridded numerical weather model outputs1. In Assignment 02, model validation against ground-based automatic weather stations (AWS) revealed [insert your Ass 02 finding, e.g., a slight underestimation of peak wind gusts / RMSE of X in temperature / bias in relative humidity during summer months].
#
# "Influence on Spatial Extreme Patterns (Ass 03 Q1): "Because FWI is non-linearly sensitive to wind speed and humidity, these model biases directly influence the spatial distribution and severity of extreme FWI nodes23. Specifically, grid-cell spatial averaging in the weather model tends to smooth out localized foehn-wind extremes across Canterbury and the North Island's East Coast. Consequently, the identified $95^{\text{th}}$ percentile spatial footprint (~67% of NZ land grid) likely reflects a macro-scale synoptic risk zone, while localized ground-level fire danger in complex terrain may be higher than modelled.
#
# "Conclusion & Operational Recommendations: "While the model-derived FWI successfully captures broad regional fire weather regimes across New Zealand, operational risk assessments by Fire Emergency New Zealand (FENZ) should pair these gridded SOM patterns with localized AWS station observations to account for model smoothing during severe wind and drought events."
#
#
# This report evaluates the spatial distribution, seasonal peak timing, and long-term climate trends of extreme Fire Weather Index (FWI) conditions across New Zealand over a 20-year observation period (2000–2020).
#
# This report evaluates the spatial distribution, seasonal peak timing, and long-term climate trends of extreme Fire Weather Index (FWI) conditions across New Zealand over a 20-year observation period (2000–2020):
#
# Question 1: Which geographic areas in New Zealand experience extreme FWI conditions under severe synoptic weather patterns?
#
# Question 2: Which specific month(s) during the four-month fire season exhibit the highest concentration of extreme fire weather?
#
# Question 3: Is the Canterbury region (represented by Darfield) experiencing a statistically significant increasing trend in extreme FWI days over the 20-year record?
#
# 2. Summary of MethodologyA. Self-Organizing Map (SOM) Clustering & Hyperparameter JustificationA $5 \times 5$ (25-node) Self-Organizing Map was trained on min-max normalized summer FWI grid maps to classify New Zealand's synoptic fire weather regimes57. Hyperparameter selection was guided by a systematic grid search evaluating Quantisation Error (QE) for map resolution and Topographic Error (TE) for feature-space topology preservation5:Optimal Configuration: Neighborhood radius $\sigma = 3.0$ and $\text{learning\_rate} = 0.1$.Performance Metrics: Achieved near-perfect topology preservation ($\text{TE} = 0.0097$, $<1\%$ topological error) while maintaining a competitive map resolution ($\text{QE} = 4.783$). The corresponding Unified Distance Matrix (U-Matrix) confirmed smooth inter-node transitions without artificial clustering boundaries.B. Thresholding & Extreme Node SelectionTo isolate extreme fire danger7:A national $95^{\text{th}}$ percentile benchmark ($\text{FWI} = 14.7849$) was calculated across all land grid pixels and fire-season timesteps ($\sim 100$ million data points)7.Each SOM node's $95^{\text{th}}$ percentile pixel map (create_percentile_maps, $p=95$) was evaluated against this benchmark7. The node containing the largest spatial footprint of grid cells exceeding $\text{FWI} = 14.7849$ was selected as the representative "extreme node"7.C. Seasonal and Trend AnalysisMonthly Histograms (Q2): Temporal frequency and spatial value-distribution histograms were constructed for December, January, February, and March across all extreme-node days6.Trend Testing (Q3): Non-parametric Mann–Kendall trend tests ($\alpha = 0.05$) and Sen’s Slope Estimators were executed for Darfield ($\text{lat} = -43.48^\circ, \text{lon} = 172.11^\circ$) across two daily time series: (1) annual counts of extreme-node days, and (2) baseline annual $90^{\text{th}}$ percentile FWI values across all fire-season days6.3. Key Findings & Discussion NarrativeQuestion 1: Spatial Distribution of Extreme FWI ConditionsHotspot Identification: Extreme FWI conditions are heavily concentrated in dry, eastern leeward regions—specifically the Canterbury Plains, Central Otago, Marlborough, Hawke's Bay, Wairarapa, and Gisborne.Climatological Driver: These regions lie in the rain shadow of the Southern Alps and axial ranges. Under severe synoptic setups, strong westerly/north-westerly winds generate Foehn drying events (e.g., the Canterbury Nor'wester). Adiabatic warming and rapid drying create high temperatures, extremely low relative humidity, and strong surface winds.Spatial Footprint: The active extreme SOM pattern impacts approximately 67% of New Zealand's land grid above the national $95^{\text{th}}$ percentile benchmark ($\text{FWI} = 14.7849$). While the synoptic state elevates risk broadly, severe values ($\text{FWI} > 30–50+$) remain tightly confined to eastern rain-shadow corridors.Question 2: Peak Fire Season MonthDominance of January: Both temporal frequency counts and spatial value histograms identify January as the peak extreme fire month by far6.Physical Mechanism: December heat initiates fuel drying, but residual spring soil moisture moderates early FWI scores. By January, weeks of intense solar radiation and evapotranspiration severely deplete soil and fine fuel moisture. Combined with mid-summer atmospheric blocking systems that drive Foehn wind events, January creates the ideal alignment of dry fuels and severe weather.Late-Season Decline: Risk remains elevated into February due to lingering drought, but decreasing solar irradiance and autumn cooling begin suppressing background FWI by March.Question 3: Canterbury Trend Analysis (Darfield)Statistical Outcome: Mann–Kendall testing revealed no statistically significant monotonic trend over the 2000–2020 period for either extreme day frequency ($p = 0.5313$) or baseline $90^{\text{th}}$ percentile FWI severity ($p = 0.2839$) at $\alpha = 0.05$6.Magnitude: Sen’s slope indicated positive trajectories ($+0.1250$ extreme days/year and $+0.1989$ FWI units/year), representing an increase of $\sim 2.5$ extreme days per decade.Climatological Rationale: The absence of a statistically significant $p$-value over 20 years is driven by strong interannual climate variability (e.g., ENSO and SAM cycles). Severe spike years (e.g., 2003/04, 2014/15, 2019/20) interspersed with damp La Niña seasons create high statistical noise that masks long-term background trends over a short $N=20$ sample. Detecting a statistically significant background signal typically requires a 30- to 50-year observation window.4. Weather Model Validation & Limitations (Assignment 02 Context)Because the FWI dataset is calculated from gridded Numerical Weather Prediction (NWP) model outputs rather than ground station instruments, model validation metrics from Assignment 02 highlight key operational limitations45:Spatial Topographic Smoothing: Gridded weather models average atmospheric variables over discrete grid cells, smoothing out hyper-localized valley wind funnels and extreme micro-climatic drops in relative humidity. Consequently, the $67\%$ spatial footprint represents a macro-scale synoptic risk zone; localized ground danger in complex terrain likely exceeds modelled values.Non-Linear Error Propagation: NWP models frequently exhibit smoothing biases during extreme tail events (underestimating peak winds or overestimating minimum humidity). Because the FWI algorithm responds non-linearly (exponentially) to wind speed and dryness, minor model underestimations result in disproportionately lower FWI scores.Conservative Baseline: The national threshold ($\text{FWI} = 14.7849$) and node maps provide a conservative synoptic baseline. Real-time station observations during active Foehn events will record higher peak spikes.5. Operational Recommendations for FENZSeasonal Resource Allocation: Focus peak national resource pre-positioning, seasonal firefighter staffing, and aerial fleet readiness heavily during the January operational window.Integrated Forecasting: Pair gridded SOM synoptic pattern maps (for early macro-scale warning) with ground-based Automatic Weather Station (AWS) data to account for model smoothing during active Foehn wind events.Volatility Management: Operational planning in Canterbury must prepare for high year-to-year volatility (severe El Niño spike seasons) rather than expecting a steady, linear annual increase.
